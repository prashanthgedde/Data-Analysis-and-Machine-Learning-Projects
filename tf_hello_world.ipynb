# %% [markdown]
# <a href="https://colab.research.google.com/github/prashanthgedde/Data-Analysis-and-Machine-Learning-Projects/blob/master/tf_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First TF notebook

# %%
import tensorflow as tf
import numpy as np

from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
print(xs)
print(ys)
# Out:
# [-1.  0.  1.  2.  3.  4.]
# [-3. -1.  1.  3.  5.  7.]

# %%
model.fit(xs, ys, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0889
# Epoch 2/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0871
# Epoch 3/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0853
# Epoch 4/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0835
# Epoch 5/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0818
# Epoch 6/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0801
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0785
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0769
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0753
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0737
# Epoch 11/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0722
# Epoch 12/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0707
# ...

# %%
print(model.predict([3,4]))
# Out:
# [[5.      ]
#  [6.999995]]

# %%
print(model.predict([10.0]))
# Out:
# [[18.999971]]
